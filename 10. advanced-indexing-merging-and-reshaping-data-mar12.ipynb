# %% [markdown]
# # Advanced Indexing, Merging and Reshaping Data

# %% [markdown]
# Data can be organized in many forms. Today, we will discuss some of these variants and methods for processing them. In addition, we will discuss some common methods for merging multiple data sources together.
#
# Friendly Reminders:
#
# * DataCamp Module - Bringing it all together! (Python Data Science Toolbox), due tonight by 11:59 p.m.
# * Homework #4 due Thursday by 11:59 p.m.
# * Project progress report due March 28 by 11:59 p.m.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## Alternative Indexing and Selection

# %% [markdown]
# We have explored several approaching for selecting values within a Series or DataFrame, including:
#
# * .loc, .iloc methods
#
# Alternatively, we can use filtering approaches to reduce a Series or DataFrame object to observations of interest.
#
# By default, when we create a Series or DataFrame object, we are assigned an Index that ranges from 0 to one less than the length of the object. Selecting values according to this default Index is not particularly convenient, because we need to know the positional location of the value. Alternatively, it can be useful to use a more meaningful index that makes it easier to find the observations that we want to select.

# %%
# Define example Series object
ser = Series(np.random.rand(10))
ser
# Out:
# 0    0.518709
# 1    0.810080
# 2    0.895074
# 3    0.700830
# 4    0.150092
# 5    0.858899
# 6    0.387727
# 7    0.064722
# 8    0.976734
# 9    0.632055
# dtype: float64

# %%
# Basic Series indexing
ser[5]
# Out:
# 0.8588992972507546

# %% [markdown]
# When importing data (primarily applicable to DataFrames), we have the option of specifying the *index_col* argument, which can set the index to a specific column of the data. This approach works well if we would like to access the values with an alternative index.

# %%
# Import video game data
# path = '/Users/seanbarnes/Dropbox/Teaching/Courses/BUDT758X/data/'
df = pd.read_csv('vgsales.csv', index_col='Rank')
df.head()
# Out:
#                           Name Platform    Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006.0        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %%
# Select row(s) via rank index
df.loc[100]
# Out:
# Name              Battlefield 3
# Platform                   X360
# Year                       2011
# Genre                   Shooter
# Publisher       Electronic Arts
# NA_Sales                   4.46
# EU_Sales                   2.13
# JP_Sales                   0.06
# Other_Sales                0.69
# Global_Sales               7.34
# Name: 100, dtype: object

# %%
# Select row(s) via filtering
df[df.index == 100]
# Out:
#                Name Platform    Year    Genre        Publisher  NA_Sales  \
# Rank
# 100   Battlefield 3     X360  2011.0  Shooter  Electronic Arts      4.46
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 100       2.13      0.06         0.69          7.34

# %% [markdown]
# Sometimes, it's useful to make adjustments to the index, based on the next step in your processing/analysis. There are two primary methods for doing this:
#
# * .set_index(*cols*, *drop*=True, *inplace*=False) - Reindex object using specific column(s) in the DataFrame
# * .reset_index(*level*, *drop*=False, *inplace*=False) - Shift one or more index levels back to DataFrame columns
#
# The *drop* argument specifies whether you want to retain the specified column/level in the new data structure.

# %%
# Reset index - drop=False
df.reset_index().head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Reset index - drop=True
df.reset_index(drop=True).head()
# Out:
#                        Name Platform    Year         Genre Publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### 2-Minute Activity

# %% [markdown]
# Create a new DataFrame (*df_nes*) that only contains NES games, then preview the first 5 rows. What do you notice about the index when you perform this filtering?

# %%
# First, reset index of inc DataFrame
df.reset_index(inplace=True)
# inplace = True, update current dataset rather than create a copy

# %%
# Then, filter to companies that operate in California
df_nes = df[df.Platform == 'NES']
df_nes.head()
# Out:
#      Rank                 Name Platform    Year     Genre Publisher  NA_Sales  \
# 1       2    Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 9      10            Duck Hunt      NES  1984.0   Shooter  Nintendo     26.93
# 22     23  Super Mario Bros. 3      NES  1988.0  Platform  Nintendo      9.54
# 96     97  Super Mario Bros. 2      NES  1988.0  Platform  Nintendo      5.39
# 127   128  The Legend of Zelda      NES  1986.0    Action  Nintendo      3.74
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1        3.58      6.81         0.77         40.24
# 9        0.63      0.28         0.47         28.31
# 22       3.44      3.84         0.46         17.28
# 96       1.18      0.70         0.19          7.46
# 127      0.93      1.69         0.14          6.51

# %%
df_nes.reset_index(drop=True).head()
# no longer need such infomation, and do not wanna such info re-join the dataset
# Out:
#    Rank                 Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     2    Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 1    10            Duck Hunt      NES  1984.0   Shooter  Nintendo     26.93
# 2    23  Super Mario Bros. 3      NES  1988.0  Platform  Nintendo      9.54
# 3    97  Super Mario Bros. 2      NES  1988.0  Platform  Nintendo      5.39
# 4   128  The Legend of Zelda      NES  1986.0    Action  Nintendo      3.74
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      3.58      6.81         0.77         40.24
# 1      0.63      0.28         0.47         28.31
# 2      3.44      3.84         0.46         17.28
# 3      1.18      0.70         0.19          7.46
# 4      0.93      1.69         0.14          6.51

# %% [markdown]
# ## Hierarchical Indexing

# %% [markdown]
# Hierarchical indexing in pandas allows you to have multiple index levels on an axis (e.g., row or column). This functionality provides us with the ability to work with higher dimensional data, but also be able to select observations in our data more directly (as in the previous example).
#
# There are multiple ways of specifying a hierarchical index (MultiIndex) for a Series or DataFrame object:
#
# 1. On creation, using the *index* or *columns* arguments for the Series or DataFrame functions
# 2. Assigning to the .index and/or .columns attributes
# 3. Using the .reindex method, specifying the *index* and/or *columns* arguments
# 4. Using the .set_index method, specifying multiple columns (e.g., as a list) to the *keys* argument
#
# A MultiIndex object is essentially a sequence of unique tuples, where each value of the tuple corresponds to a particular level of the hierarchy. Together, the values in the tuple specify the index of the observation(s). There are three ways to create a MultiIndex object:
#
# 1. pd.MultiIndex.from_arrays - Each corresponding sequence of elements are zipped into tuple of hierarchical indices
# 2. pd.MultiIndex.from_tuples - Provide list of hierarchical index tuples explicitly
# 3. pd.MultiIndex.from_product - Generates all combinations of indices with values from each iterable (level)
#
# The *from_arrays* approach (without creating the MultiIndex) is also accepted for many of the aforementioned options for specifying a hierarchical index (e.g., 1-3 above).
#
# Additional comments:
#
# * Data alignment still occurs with hierarchical indexing, so you have to be careful if performing operations or comparisons between hierarchically indexed objects.
# * Our coverage today focuses on hierarchically indexed *rows*, but the methods described apply to hierchically indexed *columns* as well
# * For additional details on MultiIndex objects and hierarchical indexing, see https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html

# %%
# MultiIndex from arrays
nums = [1,1,1,2,2,2,3,3,3]
lets = ['a','b','c'] * 3
midx = pd.MultiIndex.from_arrays([nums,lets])
midx
# Out:
# MultiIndex(levels=[[1, 2, 3], ['a', 'b', 'c']],
#            codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
ser = Series(np.random.randn(9), index=midx)
ser
# Out:
# 1  a   -1.469009
#    b    1.322576
#    c   -0.245392
# 2  a   -1.302881
#    b    1.316681
#    c    0.444896
# 3  a    1.632043
#    b    0.330817
#    c    0.583783
# dtype: float64

# %%
# Equivalent MultiIndex from tuples - Explicit
midx = pd.MultiIndex.from_tuples([(1,'a'),(1,'b'),(1,'c'),(2,'a'),(2,'b'),(2,'c'),(3,'a'),(3,'b'),(3,'c')])
midx
# Out:
# MultiIndex(levels=[[1, 2, 3], ['a', 'b', 'c']],
#            codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
# Generating tuples in a Pythonic way
tuples = list(zip(*[nums,lets]))
print(tuples)
# Out:
# [(1, 'a'), (1, 'b'), (1, 'c'), (2, 'a'), (2, 'b'), (2, 'c'), (3, 'a'), (3, 'b'), (3, 'c')]

# %%
# Equivalent MultiIndex from tuples
midx = pd.MultiIndex.from_tuples(tuples)
midx
# Out:
# MultiIndex(levels=[[1, 2, 3], ['a', 'b', 'c']],
#            codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
# Equivalent MultiIndex from product
midx = pd.MultiIndex.from_product([[1,2,3],['a','b','c']])
midx
# Out:
# MultiIndex(levels=[[1, 2, 3], ['a', 'b', 'c']],
#            codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
# Note the difference from atomic tuple indices
ser.index = tuples
ser
# Out:
# (1, a)   -1.469009
# (1, b)    1.322576
# (1, c)   -0.245392
# (2, a)   -1.302881
# (2, b)    1.316681
# (2, c)    0.444896
# (3, a)    1.632043
# (3, b)    0.330817
# (3, c)    0.583783
# dtype: float64

# %%
# .reindex method
ser = ser.reindex(index=midx)
ser
# Out:
# 1  a   -1.469009
#    b    1.322576
#    c   -0.245392
# 2  a   -1.302881
#    b    1.316681
#    c    0.444896
# 3  a    1.632043
#    b    0.330817
#    c    0.583783
# dtype: float64

# %%
# set_index method
df = df.set_index(keys=['Platform','Genre']).sort_index(level=[0,1])
df.head(10)
# Out:
#                  Rank                         Name    Year  \
# Platform Genre
# 2600     Action   736                      Frogger  1981.0
#          Action   866  E.T.: The Extra Terrestrial  1981.0
#          Action  1587                       Combat     NaN
#          Action  2234                   Spider-Man  1981.0
#          Action  2518             Custer's Revenge  1981.0
#          Action  2598                        Alien  1981.0
#          Action  2666                     Air Raid  1981.0
#          Action  2674              Crystal Castles  1983.0
#          Action  2942                    King Kong  1981.0
#          Action  3046           Adventures of Tron  1981.0
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform Genre
# 2600     Action                  Parker Bros.      2.06      0.12       0.0
#          Action                         Atari      1.84      0.11       0.0
#          Action                         Atari      1.17      0.07       0.0
#          Action                  Parker Bros.      0.87      0.05       0.0
#          Action                      Mystique      0.76      0.05       0.0
#          Action  20th Century Fox Video Games      0.74      0.04       0.0
#          Action                  Men-A-Vision      0.72      0.04       0.0
#          Action                         Atari      0.72      0.04       0.0
#          Action                   Tigervision      0.65      0.04       0.0
#          Action            Mattel Interactive      0.63      0.03       0.0
#
#                  Other_Sales  Global_Sales
# Platform Genre
# 2600     Action         0.02          2.20
#          Action         0.02          1.97
#          Action         0.01          1.25
#          Action         0.01          0.93
#          Action         0.01          0.82
#          Action         0.01          0.79
#          Action         0.01          0.77
#          Action         0.01          0.77
#          Action         0.01          0.69
#          Action         0.01          0.67

# %% [markdown]
# The advantage of hierarhical indexing over the atomic approach is that we can perform various operations across specific levels of the hierarchy:
#
# * Selection
# * Summary statistics
# * Reshaping (next)
# * Group operations (after Spring Break)

# %%
# Selecting outer level
ser[2]
# Out:
# a   -1.302881
# b    1.316681
# c    0.444896
# dtype: float64

# %%
# Selecting multiple levels
ser[2,'a']
# Out:
# -1.3028808948170674

# %%
# Selecting inner level
ser[:,'b']
# Out:
# 1    1.322576
# 2    1.316681
# 3    0.330817
# dtype: float64

# %%
# Selection - DataFrame
df.loc[('SNES', 'Platform')].head()
# Out:
#                    Rank                                       Name    Year  \
# Platform Genre
# SNES     Platform    19                          Super Mario World  1990.0
#          Platform    58                      Super Mario All-Stars  1993.0
#          Platform    72                        Donkey Kong Country  1994.0
#          Platform   188  Donkey Kong Country 2: Diddy's Kong Quest  1995.0
#          Platform   283        Super Mario World 2: Yoshi's Island  1995.0
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform Genre
# SNES     Platform  Nintendo     12.78      3.75      3.54         0.55
#          Platform  Nintendo      5.99      2.15      2.12         0.29
#          Platform  Nintendo      4.36      1.71      3.00         0.23
#          Platform  Nintendo      2.10      0.74      2.20         0.11
#          Platform  Nintendo      1.65      0.61      1.76         0.09
#
#                    Global_Sales
# Platform Genre
# SNES     Platform         20.61
#          Platform         10.55
#          Platform          9.30
#          Platform          5.15
#          Platform          4.12

# %%
# .xs method
df.xs('Sports', level=1).head()
# select 'Sports' platform
# ser[:,'b']
# Out:
#           Rank                      Name    Year   Publisher  NA_Sales  \
# Platform
# 2600      3645  The Activision Decathlon  1982.0  Activision      0.52
# 2600      3882             Fishing Derby     NaN  Activision      0.48
# 2600      4015         RealSports Tennis  1982.0       Atari      0.46
# 2600      4027                Ice Hockey  1980.0  Activision      0.46
# 2600      5958         RealSports Boxing  1986.0       Atari      0.28
#
#           EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          0.03       0.0         0.01          0.55
# 2600          0.03       0.0         0.01          0.51
# 2600          0.03       0.0         0.01          0.50
# 2600          0.03       0.0         0.01          0.49
# 2600          0.02       0.0         0.00          0.29

# %%
# Summary statistics - Series
ser.mean(level=1)
# ser.mean(level=0)
# Out:
# a   -0.379949
# b    0.990025
# c    0.261096
# dtype: float64

# %%
# Summary statistics - DataFrame
df['Global_Sales'].max(level=0).sort_values(ascending=False).head(10)
# Out:
# Platform
# Wii     82.74
# NES     40.24
# GB      31.37
# DS      30.01
# X360    21.82
# PS3     21.40
# PS2     20.81
# SNES    20.61
# GBA     15.85
# 3DS     14.35
# Name: Global_Sales, dtype: float64

# %%
df['Global_Sales'].max(level=1).sort_values(ascending=False).head(10)
# Out:
# Genre
# Sports          82.74
# Platform        40.24
# Racing          35.82
# Role-Playing    31.37
# Puzzle          30.26
# Misc            29.02
# Shooter         28.31
# Simulation      24.76
# Action          21.40
# Fighting        13.04
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Reshaping Data

# %% [markdown]
# There are several methods for reshaping data structures in pandas:
#
# * .T to transpose DataFrames (i.e., exchange rows with columns)
# * .stack, .unstack for pivoting hierarchically indexed data
# * .pivot, .melt for converting between long and wide data formats

# %% [markdown]
# ### Transpose

# %%
# Import movies data
mov = pd.read_csv('movies.csv', index_col='Film').sort_index()
mov.head()
# Out:
#                         Genre  Lead Studio  Audience  score %  Profitability  \
# Film
# (500) Days of Summer   Comedy          Fox                 81       8.096000
# 27 Dresses             Comedy          Fox                 71       5.343622
# A Dangerous Method      Drama  Independent                 89       0.448645
# A Serious Man           Drama    Universal                 64       4.382857
# Across the Universe   Romance  Independent                 84       0.652603
#
#                       Rotten Tomatoes %  Worldwide Gross  Year
# Film
# (500) Days of Summer                 87        60.720000  2009
# 27 Dresses                           40       160.308654  2008
# A Dangerous Method                   79         8.972895  2011
# A Serious Man                        89        30.680000  2009
# Across the Universe                  54        29.367143  2007

# %%
# Transpose DataFrame
mov[mov['Worldwide Gross'] > 200].head().T
# Out:
# Film              Enchanted High School Musical 3: Senior Year  \
# Genre                Comedy                             Comedy
# Lead Studio          Disney                             Disney
# Audience  score %        80                                 76
# Profitability       4.00574                            22.9131
# Rotten Tomatoes %        93                                 65
# Worldwide Gross     340.488                            252.045
# Year                   2007                               2008
#
# Film              It's Complicated Knocked Up Mamma Mia!
# Genre                       Comedy     Comedy     Comedy
# Lead Studio              Universal  Universal  Universal
# Audience  score %               63         83         76
# Profitability              2.64235     6.6364    9.23445
# Rotten Tomatoes %               56         91         53
# Worldwide Gross              224.6    219.001    609.474
# Year                          2009       2007       2008

# %% [markdown]
# ### Stack/Unstack

# %%
# Unstack inner level (default) - Pivots row index to column(s)
ser.unstack()
# transform serials to dataframe
# Out:
#           a         b         c
# 1 -1.469009  1.322576 -0.245392
# 2 -1.302881  1.316681  0.444896
# 3  1.632043  0.330817  0.583783

# %%
# Unstack specific level
ser.unstack(level=0)
# Out:
#           1         2         3
# a -1.469009 -1.302881  1.632043
# b  1.322576  1.316681  0.330817
# c -0.245392  0.444896  0.583783

# %%
# Stack - Pivotes column index into row(s)
entries = 3
mov.stack().head(entries * len(mov.columns))
# Out:
# Film
# (500) Days of Summer  Genre                     Comedy
#                       Lead Studio                  Fox
#                       Audience  score %             81
#                       Profitability              8.096
#                       Rotten Tomatoes %             87
#                       Worldwide Gross            60.72
#                       Year                        2009
# 27 Dresses            Genre                     Comedy
#                       Lead Studio                  Fox
#                       Audience  score %             71
#                       Profitability            5.34362
#                       Rotten Tomatoes %             40
#                       Worldwide Gross          160.309
#                       Year                        2008
# A Dangerous Method    Genre                      Drama
#                       Lead Studio          Independent
#                       Audience  score %             89
#                       Profitability           0.448645
#                       Rotten Tomatoes %             79
#                       Worldwide Gross          8.97289
#                       Year                        2011
# dtype: object

# %% [markdown]
# ### Pivot/Melt

# %%
# Import time series data
ts = pd.read_csv('macrodata1.csv')
ts.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
# Combine year and quarter into date
ts.insert(0, 'date', pd.PeriodIndex(year=ts.year, quarter=ts.quarter))
del ts['year'], ts['quarter']
ts.head()
# Out:
#      date   realgdp  realcons  realinv  realgovt  realdpi    cpi     m1  \
# 0  1959Q1  2710.349    1707.4  286.898   470.045   1886.9  28.98  139.7
# 1  1959Q2  2778.801    1733.7  310.859   481.301   1919.7  29.15  141.7
# 2  1959Q3  2775.488    1751.8  289.226   491.260   1916.4  29.35  140.5
# 3  1959Q4  2785.204    1753.7  299.356   484.052   1931.3  29.37  140.0
# 4  1960Q1  2847.699    1770.5  331.722   462.199   1955.5  29.54  139.6
#
#    tbilrate  unemp      pop  infl  realint
# 0      2.82    5.8  177.146  0.00     0.00
# 1      3.08    5.1  177.830  2.34     0.74
# 2      3.82    5.3  178.657  2.74     1.09
# 3      4.33    5.6  179.386  0.27     4.06
# 4      3.50    5.2  180.007  2.31     1.19

# %%
# Melt - Convert from wide to long format
ts_melt = ts.melt(id_vars='date', value_vars=['realgdp','unemp','infl']).sort_values(by='date')
ts_melt.head()
# Out:
#        date variable     value
# 0    1959Q1  realgdp  2710.349
# 203  1959Q1    unemp     5.800
# 406  1959Q1     infl     0.000
# 1    1959Q2  realgdp  2778.801
# 204  1959Q2    unemp     5.100

# %%
# Pivot - Convert from long to wide format
ts_melt.pivot(index='date', columns='variable', values='value').head()
# Out:
# variable  infl   realgdp  unemp
# date
# 1959Q1    0.00  2710.349    5.8
# 1959Q2    2.34  2778.801    5.1
# 1959Q3    2.74  2775.488    5.3
# 1959Q4    0.27  2785.204    5.6
# 1960Q1    2.31  2847.699    5.2

# %% [markdown]
# ## Merging Data

# %% [markdown]
# Oftentimes, data is stored in multiple storage entities (e.g., files, database tables, websites), and we need to combine them together. The two primary functions in padas for combining data are:
#
# * pd.concat - Concatenates (or stacks) data together, similar to Numpy functions (np.concatenate, stack variations)
# * pd.merge - Database-style merge, based on key column(s) and/or Index/MultiIndex
#
# Whether to use pd.concat or pd.merge depends on how the data structures to be combined are organized:
#
# * If the data structures are aligned in some manner (e.g., the row indices are aligned or the column indices are aligned), then concatenation is probably the correct approach
# * If you need to combine the data structures based on one or more common keys (e.g., name of person/organization/company/team, record or identification number, reference code), then pd.merge is probably more appropriate.

# %% [markdown]
# ### Concatenation

# %%
pd.concat?

# %%
# Import summer Olympics data - www.sports-reference.com
so = pd.read_html('https://www.sports-reference.com/olympics/summer/', match='City')[0]
so['Type'] = 'Summer'
so.head()
# Out:
#    Year            City        Country  Countries  Participants   Men  Women  \
# 0  2016  Rio de Janeiro         Brazil        207         11191  6147   5037
# 1  2012          London  Great Britain        205         10517  5864   4653
# 2  2008         Beijing          China        204         10902  6290   4610
# 3  2004          Athina         Greece        201         10560  6257   4303
# 4  2000          Sydney      Australia        200         10648  6579   4068
#
#    Sports  Events    Type
# 0      34     306  Summer
# 1      32     302  Summer
# 2      34     303  Summer
# 3      34     301  Summer
# 4      34     300  Summer

# %%
# Import summer Olympics data - www.sports-reference.com
wo = pd.read_html('https://www.sports-reference.com/olympics/winter/', match='City')[0]
wo['Type'] = 'Winter'
wo.head()
# Out:
#    Year            City        Country  Countries  Participants   Men  Women  \
# 0  2014           Sochi         Russia         89          2749  1643   1103
# 1  2010       Vancouver         Canada         82          2536  1503   1033
# 2  2006          Torino          Italy         79          2494  1539    955
# 3  2002  Salt Lake City  United States         77          2399  1513    886
# 4  1998          Nagano          Japan         72          2180  1390    789
#
#    Sports  Events    Type
# 0      15      98  Winter
# 1      15      86  Winter
# 2      15      84  Winter
# 3      15      78  Winter
# 4      14      68  Winter

# %%
# Concatenate DataFrames together
olympics = pd.concat([so, wo], axis=0, ignore_index=True)
olympics
# Out:
#     Year                    City        Country  Countries  Participants  \
# 0   2016          Rio de Janeiro         Brazil        207         11191
# 1   2012                  London  Great Britain        205         10517
# 2   2008                 Beijing          China        204         10902
# 3   2004                  Athina         Greece        201         10560
# 4   2000                  Sydney      Australia        200         10648
# 5   1996                 Atlanta  United States        197         10344
# 6   1992               Barcelona          Spain        169          9386
# 7   1988                   Seoul    South Korea        159          8454
# 8   1984             Los Angeles  United States        140          6799
# 9   1980                  Moskva   Soviet Union         80          5259
# 10  1976             MontrÃÂ©al         Canada         92          6073
# 11  1972              MÃÂ¼nchen   West Germany        121          7114
# 12  1968     Ciudad de MÃÂ©xico         Mexico        112          5558
# 13  1964                   Tokyo          Japan         93          5137
# 14  1960                    Roma          Italy         83          5352
# 15  1956               Melbourne      Australia         67          3189
# 16  1952                Helsinki        Finland         69          4932
# 17  1948                  London  Great Britain         59          4397
# 18  1936                  Berlin        Germany         49          4484
# 19  1932             Los Angeles  United States         47          1922
# 20  1928               Amsterdam    Netherlands         46          3250
# 21  1924                   Paris         France         45          3256
# 22  1920               Antwerpen        Belgium         29          2677
# 23  1912               Stockholm         Sweden         29          2424
# 24  1908                  London  Great Britain         22          2024
# 25  1906                  Athina         Greece         21           841
# 26  1904               St. Louis  United States         15           650
# 27  1900                   Paris         France         31          1224
# 28  1896                  Athina         Greece         12           176
# 29  2014                   Sochi         Russia         89          2749
# 30  2010               Vancouver         Canada         82          2536
# 31  2006                  Torino          Italy         79          2494
# 32  2002          Salt Lake City  United States         77          2399
# 33  1998                  Nagano          Japan         72          2180
# 34  1994             Lillehammer         Norway         67          1738
# 35  1992             Albertville         France         64          1801
# 36  1988                 Calgary         Canada         57          1427
# 37  1984                Sarajevo     Yugoslavia         49          1273
# 38  1980             Lake Placid  United States         37          1072
# 39  1976               Innsbruck        Austria         37          1129
# 40  1972                 Sapporo          Japan         35          1008
# 41  1968                Grenoble         France         37          1160
# 42  1964               Innsbruck        Austria         36          1094
# 43  1960            Squaw Valley  United States         30           665
# 44  1956       Cortina d'Ampezzo          Italy         32           821
# 45  1952                    Oslo         Norway         30           694
# 46  1948            Sankt Moritz    Switzerland         28           668
# 47  1936  Garmisch-Partenkirchen        Germany         28           668
# 48  1932             Lake Placid  United States         17           253
# 49  1928            Sankt Moritz    Switzerland         25           461
# 50  1924                Chamonix         France         19           313
#
#      Men  Women  Sports  Events    Type
# 0   6147   5037      34     306  Summer
# 1   5864   4653      32     302  Summer
# 2   6290   4610      34     303  Summer
# 3   6257   4303      34     301  Summer
# 4   6579   4068      34     300  Summer
# 5   6820   3521      31     271  Summer
# 6   6659   2721      29     257  Summer
# 7   6249   2203      27     237  Summer
# 8   5224   1567      26     221  Summer
# 9   4135   1123      23     203  Summer
# 10  4812   1260      23     198  Summer
# 11  6053   1060      23     195  Summer
# 12  4775    783      20     172  Summer
# 13  4457    680      21     163  Summer
# 14  4738    613      19     150  Summer
# 15  2818    371      18     145  Summer
# 16  4411    521      19     149  Summer
# 17  3950    446      21     149  Summer
# 18  4123    361      24     143  Summer
# 19  1721    201      18     126  Summer
# 20  2937    312      17     120  Summer
# 21  3100    156      20     130  Summer
# 22  2599     78      25     160  Summer
# 23  2356     53      17     107  Summer
# 24  1980     44      24     109  Summer
# 25   835      6      13      74  Summer
# 26   644      6      18      95  Summer
# 27  1201     23      20      95  Summer
# 28   176      0       9      43  Summer
# 29  1643   1103      15      98  Winter
# 30  1503   1033      15      86  Winter
# 31  1539    955      15      84  Winter
# 32  1513    886      15      78  Winter
# 33  1390    789      14      68  Winter
# 34  1215    522      12      61  Winter
# 35  1312    488      12      57  Winter
# 36  1109    315      11      46  Winter
# 37   996    277      10      39  Winter
# 38   837    235      10      38  Winter
# 39   897    231      10      37  Winter
# 40   802    206      10      35  Winter
# 41   949    211      10      35  Winter
# 42   894    200      10      34  Winter
# 43   521    144       8      27  Winter
# 44   689    132       8      24  Winter
# 45   585    109       8      22  Winter
# 46   591     77       9      22  Winter
# 47   588     80       8      17  Winter
# 48   231     21       8      14  Winter
# 49   433     28       8      13  Winter
# 50   300     13      10      17  Winter

# %%
# Resort DataFrame
olympics.sort_values(by=['Year','Type'], ascending=False)
# Out:
#     Year                    City        Country  Countries  Participants  \
# 0   2016          Rio de Janeiro         Brazil        207         11191
# 29  2014                   Sochi         Russia         89          2749
# 1   2012                  London  Great Britain        205         10517
# 30  2010               Vancouver         Canada         82          2536
# 2   2008                 Beijing          China        204         10902
# 31  2006                  Torino          Italy         79          2494
# 3   2004                  Athina         Greece        201         10560
# 32  2002          Salt Lake City  United States         77          2399
# 4   2000                  Sydney      Australia        200         10648
# 33  1998                  Nagano          Japan         72          2180
# 5   1996                 Atlanta  United States        197         10344
# 34  1994             Lillehammer         Norway         67          1738
# 35  1992             Albertville         France         64          1801
# 6   1992               Barcelona          Spain        169          9386
# 36  1988                 Calgary         Canada         57          1427
# 7   1988                   Seoul    South Korea        159          8454
# 37  1984                Sarajevo     Yugoslavia         49          1273
# 8   1984             Los Angeles  United States        140          6799
# 38  1980             Lake Placid  United States         37          1072
# 9   1980                  Moskva   Soviet Union         80          5259
# 39  1976               Innsbruck        Austria         37          1129
# 10  1976             MontrÃÂ©al         Canada         92          6073
# 40  1972                 Sapporo          Japan         35          1008
# 11  1972              MÃÂ¼nchen   West Germany        121          7114
# 41  1968                Grenoble         France         37          1160
# 12  1968     Ciudad de MÃÂ©xico         Mexico        112          5558
# 42  1964               Innsbruck        Austria         36          1094
# 13  1964                   Tokyo          Japan         93          5137
# 43  1960            Squaw Valley  United States         30           665
# 14  1960                    Roma          Italy         83          5352
# 44  1956       Cortina d'Ampezzo          Italy         32           821
# 15  1956               Melbourne      Australia         67          3189
# 45  1952                    Oslo         Norway         30           694
# 16  1952                Helsinki        Finland         69          4932
# 46  1948            Sankt Moritz    Switzerland         28           668
# 17  1948                  London  Great Britain         59          4397
# 47  1936  Garmisch-Partenkirchen        Germany         28           668
# 18  1936                  Berlin        Germany         49          4484
# 48  1932             Lake Placid  United States         17           253
# 19  1932             Los Angeles  United States         47          1922
# 49  1928            Sankt Moritz    Switzerland         25           461
# 20  1928               Amsterdam    Netherlands         46          3250
# 50  1924                Chamonix         France         19           313
# 21  1924                   Paris         France         45          3256
# 22  1920               Antwerpen        Belgium         29          2677
# 23  1912               Stockholm         Sweden         29          2424
# 24  1908                  London  Great Britain         22          2024
# 25  1906                  Athina         Greece         21           841
# 26  1904               St. Louis  United States         15           650
# 27  1900                   Paris         France         31          1224
# 28  1896                  Athina         Greece         12           176
#
#      Men  Women  Sports  Events    Type
# 0   6147   5037      34     306  Summer
# 29  1643   1103      15      98  Winter
# 1   5864   4653      32     302  Summer
# 30  1503   1033      15      86  Winter
# 2   6290   4610      34     303  Summer
# 31  1539    955      15      84  Winter
# 3   6257   4303      34     301  Summer
# 32  1513    886      15      78  Winter
# 4   6579   4068      34     300  Summer
# 33  1390    789      14      68  Winter
# 5   6820   3521      31     271  Summer
# 34  1215    522      12      61  Winter
# 35  1312    488      12      57  Winter
# 6   6659   2721      29     257  Summer
# 36  1109    315      11      46  Winter
# 7   6249   2203      27     237  Summer
# 37   996    277      10      39  Winter
# 8   5224   1567      26     221  Summer
# 38   837    235      10      38  Winter
# 9   4135   1123      23     203  Summer
# 39   897    231      10      37  Winter
# 10  4812   1260      23     198  Summer
# 40   802    206      10      35  Winter
# 11  6053   1060      23     195  Summer
# 41   949    211      10      35  Winter
# 12  4775    783      20     172  Summer
# 42   894    200      10      34  Winter
# 13  4457    680      21     163  Summer
# 43   521    144       8      27  Winter
# 14  4738    613      19     150  Summer
# 44   689    132       8      24  Winter
# 15  2818    371      18     145  Summer
# 45   585    109       8      22  Winter
# 16  4411    521      19     149  Summer
# 46   591     77       9      22  Winter
# 17  3950    446      21     149  Summer
# 47   588     80       8      17  Winter
# 18  4123    361      24     143  Summer
# 48   231     21       8      14  Winter
# 19  1721    201      18     126  Summer
# 49   433     28       8      13  Winter
# 20  2937    312      17     120  Summer
# 50   300     13      10      17  Winter
# 21  3100    156      20     130  Summer
# 22  2599     78      25     160  Summer
# 23  2356     53      17     107  Summer
# 24  1980     44      24     109  Summer
# 25   835      6      13      74  Summer
# 26   644      6      18      95  Summer
# 27  1201     23      20      95  Summer
# 28   176      0       9      43  Summer

# %% [markdown]
# ### Merging

# %%
pd.merge?

# %%
# Create DataFrame example 1
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                    'data': range(7)})
df1
# Out:
#   key  data
# 0   b     0
# 1   b     1
# 2   a     2
# 3   c     3
# 4   a     4
# 5   a     5
# 6   b     6

# %%
# Create DataFrame example 2
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
                    'data': range(3)})
df2
# Out:
#   key  data
# 0   a     0
# 1   b     1
# 2   d     2

# %%
# Join by key on both DataFrames - Default (how='inner'), overlapping keys only
pd.merge(df1, df2, on='key')
# Out:
#   key  data_x  data_y
# 0   b       0       1
# 1   b       1       1
# 2   b       6       1
# 3   a       2       0
# 4   a       4       0
# 5   a       5       0

# %%
# Join by key on both DataFrames - All keys
pd.merge(df1, df2, on='key', how='outer')
# Out:
#   key  data_x  data_y
# 0   b     0.0     1.0
# 1   b     1.0     1.0
# 2   b     6.0     1.0
# 3   a     2.0     0.0
# 4   a     4.0     0.0
# 5   a     5.0     0.0
# 6   c     3.0     NaN
# 7   d     NaN     2.0

# %%
# Update df2 index
df2.set_index('key', inplace=True)
df2
# Out:
#      data
# key
# a       0
# b       1
# d       2

# %%
# Merge based on index
# merge index + column, column+column, index+index
pd.merge(df1, df2, left_on='key', right_index=True, how='left', suffixes=('','_new'))
# Out:
#   key  data  data_new
# 0   b     0       1.0
# 1   b     1       1.0
# 2   a     2       0.0
# 3   c     3       NaN
# 4   a     4       0.0
# 5   a     5       0.0
# 6   b     6       1.0

# %%
df1
# Out:
#   key  data
# 0   b     0
# 1   b     1
# 2   a     2
# 3   c     3
# 4   a     4
# 5   a     5
# 6   b     6

# %% [markdown]
# ## Next Time: Data Wrangling Lab
